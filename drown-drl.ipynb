# %%
# !pip install ultralytics -q

# %%
import zipfile as Zf
import ultralytics
import matplotlib.pyplot as plt
import cv2
import pandas as pd
import seaborn as sns
import numpy as np
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

# %%
model=YOLO('yolo11n.pt')
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 67.8MB/s]

# %%
model.train(data='/kaggle/input/drown3/data.yaml' , epochs=30,pretrained=True)
# Out:
# Ultralytics 8.3.12 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r file.zip /kaggle/working
# Out:
# updating: kaggle/working/ (stored 0%)
# updating: kaggle/working/yolo11n.pt (deflated 11%)
# updating: kaggle/working/runs/ (stored 0%)
# updating: kaggle/working/runs/detect/ (stored 0%)
# updating: kaggle/working/runs/detect/train/ (stored 0%)
# updating: kaggle/working/runs/detect/train/confusion_matrix.png (deflated 40%)
# updating: kaggle/working/runs/detect/train/results.csv (deflated 60%)
# updating: kaggle/working/runs/detect/train/train_batch822.jpg (deflated 6%)
# updating: kaggle/working/runs/detect/train/R_curve.png (deflated 17%)
# updating: kaggle/working/runs/detect/train/val_batch1_labels.jpg (deflated 9%)
# updating: kaggle/working/runs/detect/train/confusion_matrix_normalized.png (deflated 38%)
# updating: kaggle/working/runs/detect/train/val_batch0_pred.jpg (deflated 7%)
# updating: kaggle/working/runs/detect/train/train_batch2.jpg (deflated 2%)
# updating: kaggle/working/runs/detect/train/weights/ (stored 0%)
# ...

# %%
from IPython.display import FileLink
FileLink(r'file.zip')
# Out:
# /kaggle/working/file.zip

# %%
results=model_new.predict('/content/R11.png',save=True,conf=0.05,agnostic_nms=True,)

# %%
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    # result.save(filename="result.jpg")

# %%
boxes.xyxy

# %%
boxes.cls

# %%
boxes

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image data using mpimg.imread
img = mpimg.imread('/content/runs/detect/predict/R11.png')

# Display the image
plt.imshow(img)
plt.show()

# %%
import numpy as np
import cv2
padded_image= np.ones(shape=(887,887),dtype=np.ubyte)
image=cv2.imread('R13.png')
Grey_image=cv2.cvtColor(np.array(image),cv2.COLOR_BGR2GRAY) #Grey image
# Grey_image=[Grey_image[:,:,0]]
padded_image[0:Grey_image.shape[0],0:Grey_image.shape[1]]=Grey_image
plt.imshow(padded_image)
cv2.imwrite('padded_image.png',padded_image)
